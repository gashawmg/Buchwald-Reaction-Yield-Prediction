# %% [markdown]
# The top 20 conditions of XGBoost obtained using 120 descriptors
# Predicting reaction performance in C–N cross-coupling using machine learning
# Experimental data obtained from Ahneman et al publication in Science DOI: 10.1126/science.aar5169

# %% [markdown]
#                                                                     Gashaw M. Goshu, June 5, 2020

# %%
# Import relevant libraries

import numpy as np
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import seaborn as sn
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
#import utils
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline

# %%
# open a file containing descriptors and yield
data = pd.read_csv(r"C:\Users\Gashaw\Documents\Descriptor_and_yield_table.csv")

# %%
data
# Out:
#       additive_*C3_NMR_shift  additive_*C3_electrostatic_charge  \
# 0                     143.12                              0.223
# 1                     143.12                              0.223
# 2                     143.12                              0.223
# 3                     143.12                              0.223
# 4                     143.12                              0.223
# ...                      ...                                ...
# 3955                  152.98                              0.429
# 3956                  152.98                              0.429
# 3957                  152.98                              0.429
# 3958                  152.98                              0.429
# 3959                  152.98                              0.429
#
#       additive_*C4_NMR_shift  additive_*C4_electrostatic_charge  \
# 0                      93.06                             -0.447
# 1                      93.06                             -0.447
# 2                      93.06                             -0.447
# 3                      93.06                             -0.447
# 4                      93.06                             -0.447
# ...                      ...                                ...
# 3955                   98.09                             -0.589
# 3956                   98.09                             -0.589
# 3957                   98.09                             -0.589
# 3958                   98.09                             -0.589
# 3959                   98.09                             -0.589
#
#       additive_*C5_NMR_shift  additive_*C5_electrostatic_charge  \
# 0                     162.34                              0.292
# 1                     162.34                              0.292
# 2                     162.34                              0.292
# 3                     162.34                              0.292
# 4                     162.34                              0.292
# ...                      ...                                ...
# 3955                  159.31                              0.387
# 3956                  159.31                              0.387
# 3957                  159.31                              0.387
# 3958                  159.31                              0.387
# 3959                  159.31                              0.387
#
#       additive_*N1_electrostatic_charge  additive_*O1_electrostatic_charge  \
# 0                                -0.334                             -0.057
# 1                                -0.334                             -0.057
# 2                                -0.334                             -0.057
# 3                                -0.334                             -0.057
# 4                                -0.334                             -0.057
# ...                                 ...                                ...
# 3955                             -0.350                             -0.068
# 3956                             -0.350                             -0.068
# 3957                             -0.350                             -0.068
# 3958                             -0.350                             -0.068
# 3959                             -0.350                             -0.068
#
#       additive_E_HOMO  additive_E_LUMO  ...  ligand_V6_frequency  \
# 0             -0.2317          -0.0487  ...             1640.307
# 1             -0.2317          -0.0487  ...             1640.307
# 2             -0.2317          -0.0487  ...             1640.307
# 3             -0.2317          -0.0487  ...             1640.307
# 4             -0.2317          -0.0487  ...             1640.307
# ...               ...              ...  ...                  ...
# 3955          -0.2337          -0.0696  ...             1631.618
# 3956          -0.2337          -0.0696  ...             1631.618
# 3957          -0.2337          -0.0696  ...             1631.618
# 3958          -0.2337          -0.0696  ...             1631.618
# 3959          -0.2337          -0.0696  ...             1631.618
#
#       ligand_V6_intensity  ligand_V7_frequency  ligand_V7_intensity  \
# 0                   4.414             3026.561               16.577
# 1                   4.414             3026.561               16.577
# 2                   4.414             3026.561               16.577
# 3                   4.414             3026.561               16.577
# 4                   4.414             3026.561               16.577
# ...                   ...                  ...                  ...
# 3955               37.445             3025.675               16.220
# 3956               37.445             3025.675               16.220
# 3957               37.445             3025.675               16.220
# 3958               37.445             3025.675               16.220
# 3959               37.445             3025.675               16.220
#
#       ligand_V8_frequency  ligand_V8_intensity  ligand_V9_frequency  \
# 0                3043.097               18.145             3064.344
# 1                3043.097               18.145             3064.344
# 2                3043.097               18.145             3064.344
# 3                3043.097               18.145             3064.344
# 4                3043.097               18.145             3064.344
# ...                   ...                  ...                  ...
# 3955             1054.500                1.432             3041.406
# 3956             1054.500                1.432             3041.406
# 3957             1054.500                1.432             3041.406
# 3958             1054.500                1.432             3041.406
# 3959             1054.500                1.432             3041.406
#
#       ligand_V9_intensity  ligand_dipole_moment      yield
# 0                  38.210              1.212924  10.657812
# 1                  38.210              1.212924  14.747896
# 2                  38.210              1.212924  18.278686
# 3                  38.210              1.212924   2.475058
# 4                  38.210              1.212924   6.119058
# ...                   ...                   ...        ...
# 3955               35.621              3.735286  57.426670
# 3956               35.621              3.735286  86.233157
# 3957               35.621              3.735286   1.440081
# 3958               35.621              3.735286  43.538365
# 3959               35.621              3.735286  69.795902
#
# [3960 rows x 121 columns]

# %%
features =["additive_*C3_NMR_shift","additive_*C4_electrostatic_charge","additive_*C4_NMR_shift",
           "additive_*C5_electrostatic_charge","additive_*O1_electrostatic_charge",         
            "additive_E_HOMO","additive_E_LUMO","additive_molecular_volume","aryl_halide_*C3_NMR_shift",
           "aryl_halide_*H2_electrostatic_charge","aryl_halide_E_LUMO","aryl_halide_V2_frequency",
           "aryl_halide_V3_frequency","base_*N1_electrostatic_charge","ligand_*C11_NMR_shift",
           "aryl_halide_*C1_electrostatic_charge","aryl_halide_*C1_NMR_shift","aryl_halide_*C2_NMR_shift",
           "base_E_HOMO","ligand_*C10_NMR_shift"]
X_data = data[features] # the top 20 descriptors identified by XGBoost from 120 descriptors 
y_data = data['yield'] # Yield of the 3560 rows is stored in the y_data variable

# %%
X_data
# Out:
#       additive_*C3_NMR_shift  additive_*C4_electrostatic_charge  \
# 0                     143.12                             -0.447
# 1                     143.12                             -0.447
# 2                     143.12                             -0.447
# 3                     143.12                             -0.447
# 4                     143.12                             -0.447
# ...                      ...                                ...
# 3955                  152.98                             -0.589
# 3956                  152.98                             -0.589
# 3957                  152.98                             -0.589
# 3958                  152.98                             -0.589
# 3959                  152.98                             -0.589
#
#       additive_*C4_NMR_shift  additive_*C5_electrostatic_charge  \
# 0                      93.06                              0.292
# 1                      93.06                              0.292
# 2                      93.06                              0.292
# 3                      93.06                              0.292
# 4                      93.06                              0.292
# ...                      ...                                ...
# 3955                   98.09                              0.387
# 3956                   98.09                              0.387
# 3957                   98.09                              0.387
# 3958                   98.09                              0.387
# 3959                   98.09                              0.387
#
#       additive_*O1_electrostatic_charge  additive_E_HOMO  additive_E_LUMO  \
# 0                                -0.057          -0.2317          -0.0487
# 1                                -0.057          -0.2317          -0.0487
# 2                                -0.057          -0.2317          -0.0487
# 3                                -0.057          -0.2317          -0.0487
# 4                                -0.057          -0.2317          -0.0487
# ...                                 ...              ...              ...
# 3955                             -0.068          -0.2337          -0.0696
# 3956                             -0.068          -0.2337          -0.0696
# 3957                             -0.068          -0.2337          -0.0696
# 3958                             -0.068          -0.2337          -0.0696
# 3959                             -0.068          -0.2337          -0.0696
#
#       additive_molecular_volume  aryl_halide_*C3_NMR_shift  \
# 0                        154.41                     120.97
# 1                        154.41                     120.95
# 2                        154.41                     181.37
# 3                        154.41                     112.08
# 4                        154.41                     112.39
# ...                         ...                        ...
# 3955                     190.33                     129.62
# 3956                     190.33                     256.46
# 3957                     190.33                     117.10
# 3958                     190.33                     117.61
# 3959                     190.33                     444.44
#
#       aryl_halide_*H2_electrostatic_charge  aryl_halide_E_LUMO  \
# 0                                    0.143             -0.0396
# 1                                    0.100             -0.0413
# 2                                    0.083             -0.0429
# 3                                    0.137             -0.0118
# 4                                    0.099             -0.3500
# ...                                    ...                 ...
# 3955                                 0.138             -0.0391
# 3956                                 0.137             -0.0383
# 3957                                 0.102             -0.0380
# 3958                                 0.065             -0.0390
# 3959                                 0.042             -0.0395
#
#       aryl_halide_V2_frequency  aryl_halide_V3_frequency  \
# 0                     1351.720                  1634.876
# 1                     1349.391                  1632.664
# 2                     1346.735                  1626.855
# 3                     1351.340                  1632.373
# 4                     1532.172                  1653.924
# ...                        ...                       ...
# 3955                  1311.840                  1626.612
# 3956                  1305.598                  1620.967
# 3957                  1298.019                  1626.114
# 3958                  1295.516                  1623.855
# 3959                  1291.420                  1619.152
#
#       base_*N1_electrostatic_charge  ligand_*C11_NMR_shift  \
# 0                            -0.755                 114.03
# 1                            -0.755                 114.03
# 2                            -0.755                 114.03
# 3                            -0.755                 114.03
# 4                            -0.755                 114.03
# ...                             ...                    ...
# 3955                         -0.611                 114.09
# 3956                         -0.611                 114.09
# 3957                         -0.611                 114.09
# 3958                         -0.611                 114.09
# 3959                         -0.611                 114.09
#
#       aryl_halide_*C1_electrostatic_charge  aryl_halide_*C1_NMR_shift  \
# 0                                    0.128                     139.77
# 1                                   -0.093                     138.83
# 2                                   -0.183                      48.97
# 3                                    0.021                     127.68
# 4                                   -0.101                     125.44
# ...                                    ...                        ...
# 3955                                 0.362                     156.88
# 3956                                 0.194                   -1201.76
# 3957                                -0.127                     134.48
# 3958                                -0.304                     133.69
# 3959                                -0.557                    -332.15
#
#       aryl_halide_*C2_NMR_shift  base_E_HOMO  ligand_*C10_NMR_shift
# 0                        122.50      -0.1703                 139.58
# 1                        125.65      -0.1703                 139.58
# 2                        111.35      -0.1703                 139.58
# 3                        123.14      -0.1703                 139.58
# 4                        126.17      -0.1703                 139.58
# ...                         ...          ...                    ...
# 3955                     122.34      -0.1913                 139.04
# 3956                     178.22      -0.1913                 139.04
# 3957                     127.98      -0.1913                 139.04
# 3958                     131.13      -0.1913                 139.04
# 3959                     -60.97      -0.1913                 139.04
#
# [3960 rows x 20 columns]

# %%
# Set the width and height of the figure
plt.figure(figsize=(15,8))
# Generate heatmap for the seven columns or descriptors
sn.heatmap(data=X_data,yticklabels=360)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_data, y_data,test_size = 0.3, random_state=1)
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
# Data preprocessing
pipe = Pipeline(steps=[
        ('preprocessor', SimpleImputer()),
        ('scale', StandardScaler()),
         ('model', rf)])

# %%
# Model Training and prediction
pipe.fit(X_train,y_train) # training using 70% of the data
predicted_yield = pipe.predict(X_valid) # predicting yield for 30% of the data

# %%
# Model accuracy using root mean square error 
rmse = np.sqrt(mean_squared_error(y_valid, predicted_yield )) 
print('rmse:', rmse)
# Out:
# rmse: 7.574713207421462

# %%
# R^2 (coefficient of determination) regression score function: 
R2 =r2_score(y_valid, predicted_yield )
print('R^2:', R2)
# Out:
# R^2: 0.9257122466933306

# %%
sn.regplot(x=predicted_yield , y=y_valid)
plt.xlabel('Predicted Yield', color='blue')
plt.ylabel('Observed Yield', color ='blue')
plt.title("Random Forest", color='red')
plt.grid(alpha=0.2)
R2 = mpatches.Patch(label="R2={:04.2f}".format(R2))
rmse = mpatches.Patch(label="RMSE={:04.2f}".format(rmse))
plt.legend(handles=[R2, rmse])

# %%
# Feature importance Random forest
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(pipe, random_state=1).fit(X_valid, y_valid)
eli5.show_weights(perm, feature_names = X_valid.columns.tolist())
# Out:
# Using TensorFlow backend.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.7405
#
#                     &plusmn; 0.0815
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_*C3_NMR_shift
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.09%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2716
#
#                     &plusmn; 0.0187
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_*H2_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2595
#
#                     &plusmn; 0.0202
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*C3_NMR_shift
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2579
#
#                     &plusmn; 0.0162
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ligand_*C11_NMR_shift
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2050
#
#                     &plusmn; 0.0171
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 base_*N1_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0711
#
#                     &plusmn; 0.0237
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 base_E_HOMO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0465
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_V2_frequency
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0349
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_E_HOMO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.05%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0266
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_E_LUMO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0201
#
#                     &plusmn; 0.0025
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*C4_NMR_shift
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0188
#
#                     &plusmn; 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*O1_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0183
#
#                     &plusmn; 0.0024
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_V3_frequency
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0181
#
#                     &plusmn; 0.0037
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_E_LUMO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0180
#
#                     &plusmn; 0.0069
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*C4_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0170
#
#                     &plusmn; 0.0028
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_molecular_volume
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0160
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*C5_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0134
#
#                     &plusmn; 0.0035
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_*C1_NMR_shift
#             </td>
#         </tr>

# %%
# XGBoost the most widely used ML model in kaggle competition
from xgboost import XGBRegressor
xgb = XGBRegressor(n_estimators=100, random_state=42)

# %%
pipe2 = Pipeline(steps=[
        ('scale', StandardScaler()),
        ('preprocessor', SimpleImputer()),
        ('model', xgb)])

# %%
# Model Training and prediction
pipe2.fit(X_train,y_train) # training using 70% of the data
predicted_yield2 = pipe2.predict(X_valid) # predicting yield for 30% of the data

# %%
# Model accuracy using root mean square error 
rmse2 = np.sqrt(mean_squared_error(y_valid, predicted_yield2))  
print('rmse:', rmse2)
# Out:
# rmse: 6.694470870774241

# %%
# R^2 (coefficient of determination) regression score function: 
R_2 =r2_score(y_valid, predicted_yield2)
print('R^2:', R_2)
# Out:
# R^2: 0.941974706227155

# %%
sn.regplot(x=predicted_yield2, y=y_valid)
plt.xlabel('Predicted Yield', color='blue')
plt.ylabel('Observed Yield', color ='blue')
plt.title("XGBoost", color='red')
plt.grid(alpha=0.2)
R_2 = mpatches.Patch(label="R2={:04.2f}".format(R_2))
rmse2 = mpatches.Patch(label="RMSE={:04.2f}".format(rmse2))
plt.legend(handles=[R_2, rmse2])

# %%
# Feature importance Random forest
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(pipe2, random_state=1).fit(X_valid, y_valid)
eli5.show_weights(perm, feature_names = X_valid.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.5282
#
#                     &plusmn; 0.0637
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_*C3_NMR_shift
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2856
#
#                     &plusmn; 0.0177
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ligand_*C11_NMR_shift
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1975
#
#                     &plusmn; 0.0209
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*C3_NMR_shift
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1913
#
#                     &plusmn; 0.0226
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_*H2_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1506
#
#                     &plusmn; 0.0121
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 base_*N1_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0995
#
#                     &plusmn; 0.0287
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 base_E_HOMO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0586
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_E_LUMO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0515
#
#                     &plusmn; 0.0102
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*C4_NMR_shift
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0429
#
#                     &plusmn; 0.0029
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_V2_frequency
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0372
#
#                     &plusmn; 0.0029
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 aryl_halide_V3_frequency
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0303
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*C4_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0234
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_E_HOMO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0209
#
#                     &plusmn; 0.0044
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_E_LUMO
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0183
#
#                     &plusmn; 0.0029
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*C5_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0154
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_*O1_electrostatic_charge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0127
#
#                     &plusmn; 0.0038
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 additive_molecular_volume
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0104
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ligand_*C10_NMR_shift
#             </td>
#         </tr>
#
#         <tr
